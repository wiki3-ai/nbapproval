# %% [markdown]
# # Holiday Calendar (Idiomatic Notebook)
#
# This notebook uses the well-supported `holidays` package to generate holiday dates with a concise, notebook-first workflow.

# %%
# Notebook parameters
start_year = 2024
end_year = 2028
country = "US"
subdiv = None  # Example: "CA" for California

# %%
# Install once per environment if needed
# %pip -q install holidays nbapproval
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import holidays

# %%
# Build a tidy holiday table
years = range(start_year, end_year + 1)
cal = holidays.country_holidays(country, subdiv=subdiv, years=years, observed=True)

df = (
    pd.Series(cal, name="Holiday")
    .rename_axis("Date")
    .sort_index()
    .reset_index()
)

df["Date"] = pd.to_datetime(df["Date"])
df["Year"] = df["Date"].dt.year
df["Weekday"] = df["Date"].dt.day_name()

df.head(10)
# Out:
#         Date                               Holiday  Year    Weekday
# 0 2024-01-01                        New Year's Day  2024     Monday
# 1 2024-01-15            Martin Luther King Jr. Day  2024     Monday
# 2 2024-02-19                 Washington's Birthday  2024     Monday
# 3 2024-05-27                          Memorial Day  2024     Monday
# 4 2024-06-19  Juneteenth National Independence Day  2024  Wednesday
# 5 2024-07-04                      Independence Day  2024   Thursday
# 6 2024-09-02                             Labor Day  2024     Monday
# 7 2024-10-14                          Columbus Day  2024     Monday
# 8 2024-11-11                          Veterans Day  2024     Monday
# 9 2024-11-28                      Thanksgiving Day  2024   Thursday

# %%
# Compact yearly summary
summary = (
    df.groupby("Year", as_index=False)
    .agg(Holiday_Count=("Holiday", "count"))
)
summary
# Out:
#    Year  Holiday_Count
# 0  2024             11
# 1  2025             11
# 2  2026             12
# 3  2027             15
# 4  2028             12

# %%
# Inspect one year
year = 2026
df.loc[df["Year"] == year, ["Date", "Weekday", "Holiday"]].reset_index(drop=True)
# Out:
#          Date    Weekday                               Holiday
# 0  2026-01-01   Thursday                        New Year's Day
# 1  2026-01-19     Monday            Martin Luther King Jr. Day
# 2  2026-02-16     Monday                 Washington's Birthday
# 3  2026-05-25     Monday                          Memorial Day
# 4  2026-06-19     Friday  Juneteenth National Independence Day
# 5  2026-07-03     Friday           Independence Day (observed)
# 6  2026-07-04   Saturday                      Independence Day
# 7  2026-09-07     Monday                             Labor Day
# 8  2026-10-12     Monday                          Columbus Day
# 9  2026-11-11  Wednesday                          Veterans Day
# 10 2026-11-26   Thursday                      Thanksgiving Day
# 11 2026-12-25     Friday                         Christmas Day

# %% [markdown]
# ## Quick Validation Tests
#
# Each test is a single code cell that shows expected vs actual values as notebook output.
# Assertions enforce correctness without print-based status messages.

# %%
from nbapproval import approval_test

# %%
# Test 1: required columns are present (one-cell test)
actual_columns = sorted(df.columns.tolist())
required = ["Date", "Holiday", "Weekday", "Year"]
missing = [c for c in required if c not in actual_columns]
assert not missing, f"Missing columns: {missing}"

# %%
approval_test(
    id="dataframe_includes_required_columns",
    description="Dataframe includes required columns",
    actual=df.columns.tolist(),
)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "dataframe_includes_required_columns",
#   "description": "Dataframe includes required columns",
#   "value": [
#     "Date",
#     "Holiday",
#     "Year",
#     "Weekday"
#   ],
#   "expectedValue": [
#     "Date",
#     "Holiday",
#     "Year",
#     "Weekday"
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
# %approve Dataframe includes required columns :: df.columns.tolist()
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "dataframe_includes_required_columns",
#   "description": "Dataframe includes required columns",
#   "value": [
#     "Date",
#     "Holiday",
#     "Year",
#     "Weekday"
#   ],
#   "expectedValue": [
#     "Date",
#     "Holiday",
#     "Year",
#     "Weekday"
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %% [markdown]
# If just the expression is provided then that becomes the description which becomes the id.

# %%
# %approve bool(df["Date"].is_monotonic_increasing)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "bool_df_date_is_monotonic_increasing",
#   "description": "bool(df[\"Date\"].is_monotonic_increasing)",
#   "value": true,
#   "expectedValue": true,
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
# Test 2: year boundaries are correct (one-cell test)
actual_min = int(df["Year"].min())
actual_max = int(df["Year"].max())
assert actual_min == start_year, f"Start year mismatch: expected {start_year}, got {actual_min}"
assert actual_max == end_year, f"End year mismatch: expected {end_year}, got {actual_max}"

# %%
approval_test("First year matches start_year parameter", int(df["Year"].min())==start_year)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "first_year_matches_start_year_parameter",
#   "description": "First year matches start_year parameter",
#   "value": true,
#   "expectedValue": true,
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
approval_test("Last year matches end_year parameter", int(df["Year"].max())==end_year)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "last_year_matches_end_year_parameter",
#   "description": "Last year matches end_year parameter",
#   "value": true,
#   "expectedValue": true,
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
# Test 3: date ordering and weekday derivation (one-cell test)
is_sorted = bool(df["Date"].is_monotonic_increasing)
weekday_match = bool((df["Date"].dt.day_name() == df["Weekday"]).all())
assert is_sorted, "Dates are not sorted ascending"
assert weekday_match, "Weekday values do not match Date"

# %%
approval_test("Dates are sorted", bool(df["Date"].is_monotonic_increasing))
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "dates_are_sorted",
#   "description": "Dates are sorted",
#   "value": true,
#   "expectedValue": true,
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
weekday_names = pd.DataFrame({"Date_day_name": df["Date"].dt.day_name(), "Weekday": df["Weekday"]})

# %approve Date day names and derived weekday names :: weekday_names
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "date_day_names_and_derived_weekday_names",
#   "description": "Date day names and derived weekday names",
#   "value": [
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Tuesday",
#       "Weekday": "Tuesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Sunday",
#       "Weekday": "Sunday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Tuesday",
#       "Weekday": "Tuesday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     }
#   ],
#   "expectedValue": [
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Tuesday",
#       "Weekday": "Tuesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Sunday",
#       "Weekday": "Sunday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Tuesday",
#       "Weekday": "Tuesday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     }
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
approval_test(
    "Weekday text matches derived weekday names",
    bool((weekday_names["Date_day_name"] == weekday_names["Weekday"]).all())
)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "weekday_text_matches_derived_weekday_names",
#   "description": "Weekday text matches derived weekday names",
#   "value": true,
#   "expectedValue": true,
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %% [markdown]
# # Test 4: known holiday spot checks (one-cell test)

# %%
# %%approve Known holiday checkpoints match expected names for specific dates --sort-by "['Date', 'Holiday']"
# known = pd.DataFrame([
#     {"Date": pd.Timestamp("2024-01-01"), "Holiday": "New Year's Day"},
#     {"Date": pd.Timestamp("2024-11-28"), "Holiday": "Thanksgiving Day"},
#     {"Date": pd.Timestamp("2026-05-25"), "Holiday": "Memorial Day"},
# ])
#
# actual = (
#     df[df["Date"].isin(known["Date"])]
#     .loc[:, ["Date", "Holiday"]]
#     .sort_values("Date")
#     .reset_index(drop=True)
# )
#
# approval_test.to_iso_records(actual)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "known_holiday_checkpoints_match_expected_names_for_specific_dates",
#   "description": "Known holiday checkpoints match expected names for specific dates",
#   "value": [
#     {
#       "Date": "2024-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2024-11-28",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     }
#   ],
#   "expectedValue": [
#     {
#       "Date": "2024-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2024-11-28",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     }
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %% [markdown]
# ### Notebook Testing Patterns In Practice
#
# - ipytest: run pytest directly inside notebook cells via magics.
# - nbval or pytest-notebook: rerun whole notebooks and compare stored outputs, usually in CI.
# - testbook: write tests in separate Python files against notebook code.
# - ApprovalTests.Python: classic approved vs received workflow with diff tools.
#
# This notebook uses per-cell approved tables so each test visibly shows Approved and Actual values in one place.

# %%
# Approval test 1: full 2026 holiday list
approval_test(
    "Federal holidays for 2026 (including observed).",
    df.loc[df["Year"] == 2026, ["Date", "Holiday"]],
    sort_by=["Date", "Holiday"],
)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "federal_holidays_for_2026_including_observed",
#   "description": "Federal holidays for 2026 (including observed).",
#   "value": [
#     {
#       "Date": "2026-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2026-01-19",
#       "Holiday": "Martin Luther King Jr. Day"
#     },
#     {
#       "Date": "2026-02-16",
#       "Holiday": "Washington's Birthday"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     },
#     {
#       "Date": "2026-06-19",
#       "Holiday": "Juneteenth National Independence Day"
#     },
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     },
#     {
#       "Date": "2026-09-07",
#       "Holiday": "Labor Day"
#     },
#     {
#       "Date": "2026-10-12",
#       "Holiday": "Columbus Day"
#     },
#     {
#       "Date": "2026-11-11",
#       "Holiday": "Veterans Day"
#     },
#     {
#       "Date": "2026-11-26",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-12-25",
#       "Holiday": "Christmas Day"
#     }
#   ],
#   "expectedValue": [
#     {
#       "Date": "2026-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2026-01-19",
#       "Holiday": "Martin Luther King Jr. Day"
#     },
#     {
#       "Date": "2026-02-16",
#       "Holiday": "Washington's Birthday"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     },
#     {
#       "Date": "2026-06-19",
#       "Holiday": "Juneteenth National Independence Day"
#     },
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     },
#     {
#       "Date": "2026-09-07",
#       "Holiday": "Labor Day"
#     },
#     {
#       "Date": "2026-10-12",
#       "Holiday": "Columbus Day"
#     },
#     {
#       "Date": "2026-11-11",
#       "Holiday": "Veterans Day"
#     },
#     {
#       "Date": "2026-11-26",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-12-25",
#       "Holiday": "Christmas Day"
#     }
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
# %%approve Federal holidays for 2026 (including observed). --sort-by "['Date', 'Holiday']"
# df.loc[df["Year"] == 2026, ["Date", "Holiday"]]
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "federal_holidays_for_2026_including_observed",
#   "description": "Federal holidays for 2026 (including observed).",
#   "value": [
#     {
#       "Date": "2026-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2026-01-19",
#       "Holiday": "Martin Luther King Jr. Day"
#     },
#     {
#       "Date": "2026-02-16",
#       "Holiday": "Washington's Birthday"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     },
#     {
#       "Date": "2026-06-19",
#       "Holiday": "Juneteenth National Independence Day"
#     },
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     },
#     {
#       "Date": "2026-09-07",
#       "Holiday": "Labor Day"
#     },
#     {
#       "Date": "2026-10-12",
#       "Holiday": "Columbus Day"
#     },
#     {
#       "Date": "2026-11-11",
#       "Holiday": "Veterans Day"
#     },
#     {
#       "Date": "2026-11-26",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-12-25",
#       "Holiday": "Christmas Day"
#     }
#   ],
#   "expectedValue": [
#     {
#       "Date": "2026-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2026-01-19",
#       "Holiday": "Martin Luther King Jr. Day"
#     },
#     {
#       "Date": "2026-02-16",
#       "Holiday": "Washington's Birthday"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     },
#     {
#       "Date": "2026-06-19",
#       "Holiday": "Juneteenth National Independence Day"
#     },
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     },
#     {
#       "Date": "2026-09-07",
#       "Holiday": "Labor Day"
#     },
#     {
#       "Date": "2026-10-12",
#       "Holiday": "Columbus Day"
#     },
#     {
#       "Date": "2026-11-11",
#       "Holiday": "Veterans Day"
#     },
#     {
#       "Date": "2026-11-26",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-12-25",
#       "Holiday": "Christmas Day"
#     }
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
# Approval test 2: Independence Day observed behavior in 2026
approval_test(
    "Observed Independence Day appears on Friday when July 4 is Saturday.",
    df.loc[
        (df["Date"].between(pd.Timestamp("2026-07-03"), pd.Timestamp("2026-07-04")))
        & (df["Holiday"].str.contains("Independence Day")),
        ["Date", "Holiday"]],
    sort_by=["Date", "Holiday"],
    id="independence_day_observed_2026"
)
# Out:
# {
#   "@context": {
#     "@vocab": "https://schema.org/"
#   },
#   "@type": "PropertyValue",
#   "name": "independence_day_observed_2026",
#   "description": "Observed Independence Day appears on Friday when July 4 is Saturday.",
#   "value": [
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     }
#   ],
#   "expectedValue": [
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     }
#   ],
#   "result": true,
#   "additionalProperty": [
#     {
#       "@type": "PropertyValue",
#       "name": "status",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "decision",
#       "value": "Approved"
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "diff",
#       "value": []
#     },
#     {
#       "@type": "PropertyValue",
#       "name": "approvalsNotebook",
#       "value": "/workspaces/coding/__approvals__/holiday_calculator_tested.ipynb"
#     }
#   ]
# }
# VBox(children=(HBox(children=(ToggleButton(value=True, button_style='success', description='Approved', icon='c…

# %%
# CI/Papermill guard: fail run when any approval test is not approved
approval_test.assert_all_approved()
# Out:
# Approval summary: 10/10 Approved (Pending=0, changed=0, Disapproved=0, missing-approved=0)
# Approvals notebook: /workspaces/coding/__approvals__/holiday_calculator_tested.ipynb
