# %% [raw]
# {
#   "test_id": "required_columns_present",
#   "approved": [
#     "Date",
#     "Holiday",
#     "Year",
#     "Weekday"
#   ],
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "observed_year_range_matches_configured_notebook_parameters",
#   "approved": {
#     "startYear": 2024,
#     "endYear": 2028
#   },
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "dates_are_sorted",
#   "approved": true,
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "date_day_names_and_derived_weekday_names",
#   "approved": [
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Tuesday",
#       "Weekday": "Tuesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Wednesday",
#       "Weekday": "Wednesday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Sunday",
#       "Weekday": "Sunday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Tuesday",
#       "Weekday": "Tuesday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     },
#     {
#       "Date_day_name": "Friday",
#       "Weekday": "Friday"
#     },
#     {
#       "Date_day_name": "Saturday",
#       "Weekday": "Saturday"
#     },
#     {
#       "Date_day_name": "Thursday",
#       "Weekday": "Thursday"
#     },
#     {
#       "Date_day_name": "Monday",
#       "Weekday": "Monday"
#     }
#   ],
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "weekday_text_matches_derived_weekday_names",
#   "approved": true,
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "known_holiday_checkpoints_match_expected_names_for_specific_dates",
#   "approved": [
#     {
#       "Date": "2024-01-01",
#       "Expected": "New Year's Day"
#     },
#     {
#       "Date": "2024-11-28",
#       "Expected": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-05-25",
#       "Expected": "Memorial Day"
#     }
#   ],
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "federal_holidays_for_2026_including_observed",
#   "approved": [
#     {
#       "Date": "2026-01-01",
#       "Holiday": "New Year's Day"
#     },
#     {
#       "Date": "2026-01-19",
#       "Holiday": "Martin Luther King Jr. Day"
#     },
#     {
#       "Date": "2026-02-16",
#       "Holiday": "Washington's Birthday"
#     },
#     {
#       "Date": "2026-05-25",
#       "Holiday": "Memorial Day"
#     },
#     {
#       "Date": "2026-06-19",
#       "Holiday": "Juneteenth National Independence Day"
#     },
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     },
#     {
#       "Date": "2026-09-07",
#       "Holiday": "Labor Day"
#     },
#     {
#       "Date": "2026-10-12",
#       "Holiday": "Columbus Day"
#     },
#     {
#       "Date": "2026-11-11",
#       "Holiday": "Veterans Day"
#     },
#     {
#       "Date": "2026-11-26",
#       "Holiday": "Thanksgiving Day"
#     },
#     {
#       "Date": "2026-12-25",
#       "Holiday": "Christmas Day"
#     }
#   ],
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "independence_day_observed_2026",
#   "approved": [
#     {
#       "Date": "2026-07-03",
#       "Holiday": "Independence Day (observed)"
#     },
#     {
#       "Date": "2026-07-04",
#       "Holiday": "Independence Day"
#     }
#   ],
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "first_year_matches_start_year_parameter",
#   "approved": true,
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "last_year_matches_end_year_parameter",
#   "approved": true,
#   "decision": "Approved"
# }

# %% [raw]
# {
#   "test_id": "dataframe_includes_required_columns",
#   "approved": [
#     "Date",
#     "Holiday",
#     "Year",
#     "Weekday"
#   ],
#   "decision": "Approved"
# }
